# %%
#download dataset from roboflow
from roboflow import Roboflow
rf = Roboflow(api_key="MQETUo8am1jiYCPlPa0l")
project = rf.workspace("project-spapm").project("trafic-sin")
dataset = project.version(1).download("yolov8")
# Out:
# loading Roboflow workspace...
# loading Roboflow project...
# Dependency ultralytics<=8.0.20 is required but found version=8.0.132, to fix: `pip install ultralytics<=8.0.20`
# ...
# Extracting Dataset Version Zip to trafic-sin-1 in yolov8:: 100%|██████████| 1762/1762 [00:01<00:00, 1020.45it/s]

# %%
from ultralytics import YOLO

# Load the model.
model = YOLO('yolov8n.pt')

# %%
# Training.
results = model.train(
   data='C:/salman/sir pro/trafic-sin-1/data.yaml',
   epochs=100)
# Out:
# New https://pypi.org/project/ultralytics/8.0.173 available  Update with 'pip install -U ultralytics'
# Ultralytics YOLOv8.0.132  Python-3.11.4 torch-2.0.1+cpu CPU
# ...

# %%
model.train(resume=True)
# Out:
# Ultralytics YOLOv8.0.132  Python-3.11.4 torch-2.0.1+cpu CPU
# ...

# %%
#Validate with a new model
results = model.val (
   data='C:/salman/sir pro/trafic-sin-1/data.yaml',
   )
# Out:
# Ultralytics YOLOv8.0.132  Python-3.11.4 torch-2.0.1+cpu CPU
# Model summary (fused): 168 layers, 3006428 parameters, 0 gradients, 8.1 GFLOPs
# val: Scanning C:\salman\sir pro\trafic-sin-1\valid\labels.cache... 174 images, 0 backgrounds, 0 corrupt: 100%|██████████| 174/174 [00:00<?, ?it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 11/11 [00:56<00:00,  5.13s/it]
#                    all        174        229      0.976       0.91      0.952      0.817
#              crosswalk        174         32      0.941      0.988      0.987      0.836
#             speedlimit        174        158      0.987      0.985      0.995      0.909
#                   stop        174         17      0.974      0.941      0.951      0.889
#           trafficlight        174         22          1      0.725      0.876      0.632
# Speed: 3.9ms preprocess, 303.2ms inference, 0.0ms loss, 1.3ms postprocess per image
# ...

# %%
from ultralytics import YOLO
import imutils
from ultralytics.yolo.utils.plotting import Annotator
model = YOLO('C:/salman/sir_pro/runs/detect/train/weights/best.pt')
# Out:
# WARNING  'ultralytics.yolo.v8' is deprecated since '8.0.136' and will be removed in '8.1.0'. Please use 'ultralytics.models.yolo' instead.
# WARNING  'ultralytics.yolo.utils' is deprecated since '8.0.136' and will be removed in '8.1.0'. Please use 'ultralytics.utils' instead.
# Note this warning may be related to loading older models. You can update your model to current structure with:
#     import torch
#     ckpt = torch.load("model.pt")  # applies to both official and custom models
#     torch.save(ckpt, "updated-model.pt")
